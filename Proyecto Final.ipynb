# %%
import numpy as np
import pandas as pd
import math
import statistics
import scipy.stats
import datetime
import matplotlib.pyplot as plt

# %%
DevOps = pd.read_csv("Tareas2.csv")

# %%
DevOps.head(10)
# Out:
#      ID Work Item Type                                              Title  \
# 0  8153     User Story                  Pase a producción del job TMTO202
# 1  8155     User Story  Modificación y eliminación de CyB en pipelines...
# 2  8157     User Story  Validación de Imperdonables con Agrupación Est...
# 3  8159     User Story         Retirar precio lista de notebook Customers
# 4  8162     User Story   migración de MX a PE - ajuste proceso diario PS
# 5  8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6  8168     User Story  Plataforma PS: Formato de entregas para client...
# 7  8169     User Story  PxC: Integración de producto competencia a Ped...
# 8  8179     User Story                         Fix NB reporte mensual PdV
# 9  8185     User Story                 PdV Verificación de elite sampling
#
#                                     Assigned To   State Tags  \
# 0  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 1  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 2  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 3     Carlos Aquino <carlos.aquinop@lindley.pe>  Closed  NaN
# 4     DS Michael <michael.quintanah@lindley.pe>  Closed  NaN
# 5     César Rocha <cesar.rochah@arcacontal.com>  Closed  NaN
# 6     César Rocha <cesar.rochah@arcacontal.com>  Closed  NaN
# 7     César Rocha <cesar.rochah@arcacontal.com>     New  NaN
# 8      arnold.condor <arnold.condor@lindley.pe>  Closed  NaN
# 9    Isidro Reyes <isidro.reyes@arcacontal.com>  Closed  NaN
#
#                   Iteration Path         Closed Date     Activated Date  \
# 0  MXAdvancedAnalytics\Sprint 81   1/9/2022 09:04:10  1/9/2022 09:03:57
# 1  MXAdvancedAnalytics\Sprint 81   2/9/2022 18:21:42  1/9/2022 09:07:27
# 2  MXAdvancedAnalytics\Sprint 81   1/9/2022 13:08:56  1/9/2022 12:54:49
# 3  PEAdvancedAnalytics\Sprint 43   1/9/2022 16:57:07  1/9/2022 16:15:39
# 4  PEAdvancedAnalytics\Sprint 43   9/9/2022 10:13:40  9/9/2022 10:05:17
# 5  MXAdvancedAnalytics\Sprint 82  23/9/2022 18:02:40  1/9/2022 20:01:13
# 6  MXAdvancedAnalytics\Sprint 82  23/9/2022 18:02:40  1/9/2022 20:04:43
# 7  MXAdvancedAnalytics\Sprint 83                 NaN                NaN
# 8  PEAdvancedAnalytics\Sprint 43   2/9/2022 08:33:48  2/9/2022 07:54:26
# 9  MXAdvancedAnalytics\Sprint 81   5/9/2022 09:12:24  2/9/2022 09:15:59
#
#         Created Date                                        Description
# 0  1/9/2022 09:03:27  <div>Enviar a producción (correo a Mireles) de...
# 1  1/9/2022 09:07:04  <div>Modificar pipeline de PS para eliminar lo...
# 2  1/9/2022 12:30:55  <div>Validar cambios en imperdonables con arch...
# 3  1/9/2022 16:15:35  <div>Se debe eliminar la fuente de Precio list...
# 4  1/9/2022 18:17:30  <div>migración del ajuste diario en PS - adapt...
# 5  1/9/2022 19:47:08  <div>Se integrará la fuente de ordenes del día...
# 6  1/9/2022 19:48:17  <div>Para el release de Plataforma PS, el equi...
# 7  1/9/2022 19:50:35  <div>Se define y desarrolla la lógica en que s...
# 8  2/9/2022 07:51:58  <div>Se revisará el motivo de error en la entr...
# 9  2/9/2022 09:07:22  <div>Verificar el código que realiza el sampli...

# %%
check_for_nan = DevOps["Iteration Path"].isnull()
print (check_for_nan)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 214    False
# 215    False
# 216    False
# 217    False
# 218    False
# Name: Iteration Path, Length: 219, dtype: bool

# %%
DevOps1 = DevOps["Assigned To"].str.split("<", n = 1, expand = True)
DevOps1
# Out:
#                         0                                  1
# 0          Carlos Prieto       carlos.prieto@arcacontal.com>
# 1          Carlos Prieto       carlos.prieto@arcacontal.com>
# 2          Carlos Prieto       carlos.prieto@arcacontal.com>
# 3          Carlos Aquino          carlos.aquinop@lindley.pe>
# 4             DS Michael       michael.quintanah@lindley.pe>
# ..                    ...                                ...
# 214  EDMUNDO REYES JAIME   edmundo.reyes@ext.arcacontal.com>
# 215        arnold.condor           arnold.condor@lindley.pe>
# 216        arnold.condor           arnold.condor@lindley.pe>
# 217           DS Michael       michael.quintanah@lindley.pe>
# 218       raul.martinezt      raul.martinezt@arcacontal.com>
#
# [219 rows x 2 columns]

# %%
DevOps["Assigned to Name"]= DevOps1[0]
DevOps["Assigned to Email"]= DevOps1[1]

# %%
DevOps.head(5)
# Out:
#      ID Work Item Type                                              Title  \
# 0  8153     User Story                  Pase a producción del job TMTO202
# 1  8155     User Story  Modificación y eliminación de CyB en pipelines...
# 2  8157     User Story  Validación de Imperdonables con Agrupación Est...
# 3  8159     User Story         Retirar precio lista de notebook Customers
# 4  8162     User Story   migración de MX a PE - ajuste proceso diario PS
#
#                                     Assigned To   State Tags  \
# 0  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 1  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 2  Carlos Prieto <carlos.prieto@arcacontal.com>  Closed  NaN
# 3     Carlos Aquino <carlos.aquinop@lindley.pe>  Closed  NaN
# 4     DS Michael <michael.quintanah@lindley.pe>  Closed  NaN
#
#                   Iteration Path        Closed Date     Activated Date  \
# 0  MXAdvancedAnalytics\Sprint 81  1/9/2022 09:04:10  1/9/2022 09:03:57
# 1  MXAdvancedAnalytics\Sprint 81  2/9/2022 18:21:42  1/9/2022 09:07:27
# 2  MXAdvancedAnalytics\Sprint 81  1/9/2022 13:08:56  1/9/2022 12:54:49
# 3  PEAdvancedAnalytics\Sprint 43  1/9/2022 16:57:07  1/9/2022 16:15:39
# 4  PEAdvancedAnalytics\Sprint 43  9/9/2022 10:13:40  9/9/2022 10:05:17
#
#         Created Date                                        Description  \
# 0  1/9/2022 09:03:27  <div>Enviar a producción (correo a Mireles) de...
# 1  1/9/2022 09:07:04  <div>Modificar pipeline de PS para eliminar lo...
# 2  1/9/2022 12:30:55  <div>Validar cambios en imperdonables con arch...
# 3  1/9/2022 16:15:35  <div>Se debe eliminar la fuente de Precio list...
# 4  1/9/2022 18:17:30  <div>migración del ajuste diario en PS - adapt...
#
#   Assigned to Name              Assigned to Email
# 0   Carlos Prieto   carlos.prieto@arcacontal.com>
# 1   Carlos Prieto   carlos.prieto@arcacontal.com>
# 2   Carlos Prieto   carlos.prieto@arcacontal.com>
# 3   Carlos Aquino      carlos.aquinop@lindley.pe>
# 4      DS Michael   michael.quintanah@lindley.pe>

# %%
DevOps.drop(columns =["Assigned To"], inplace = True)

# %%
DO2 = DevOps["Assigned to Email"].str.split(">", n = 1, expand = True)

# %%
DevOps["Email"]= DO2[0]
DevOps["Email2"]= DO2[1]
DevOps.head()
# Out:
#      ID Work Item Type                                              Title  \
# 0  8153     User Story                  Pase a producción del job TMTO202
# 1  8155     User Story  Modificación y eliminación de CyB en pipelines...
# 2  8157     User Story  Validación de Imperdonables con Agrupación Est...
# 3  8159     User Story         Retirar precio lista de notebook Customers
# 4  8162     User Story   migración de MX a PE - ajuste proceso diario PS
#
#     State Tags                 Iteration Path        Closed Date  \
# 0  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 09:04:10
# 1  Closed  NaN  MXAdvancedAnalytics\Sprint 81  2/9/2022 18:21:42
# 2  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 13:08:56
# 3  Closed  NaN  PEAdvancedAnalytics\Sprint 43  1/9/2022 16:57:07
# 4  Closed  NaN  PEAdvancedAnalytics\Sprint 43  9/9/2022 10:13:40
#
#       Activated Date       Created Date  \
# 0  1/9/2022 09:03:57  1/9/2022 09:03:27
# 1  1/9/2022 09:07:27  1/9/2022 09:07:04
# 2  1/9/2022 12:54:49  1/9/2022 12:30:55
# 3  1/9/2022 16:15:39  1/9/2022 16:15:35
# 4  9/9/2022 10:05:17  1/9/2022 18:17:30
#
#                                          Description Assigned to Name  \
# 0  <div>Enviar a producción (correo a Mireles) de...   Carlos Prieto
# 1  <div>Modificar pipeline de PS para eliminar lo...   Carlos Prieto
# 2  <div>Validar cambios en imperdonables con arch...   Carlos Prieto
# 3  <div>Se debe eliminar la fuente de Precio list...   Carlos Aquino
# 4  <div>migración del ajuste diario en PS - adapt...      DS Michael
#
#                Assigned to Email                         Email Email2
# 0  carlos.prieto@arcacontal.com>  carlos.prieto@arcacontal.com
# 1  carlos.prieto@arcacontal.com>  carlos.prieto@arcacontal.com
# 2  carlos.prieto@arcacontal.com>  carlos.prieto@arcacontal.com
# 3     carlos.aquinop@lindley.pe>     carlos.aquinop@lindley.pe
# 4  michael.quintanah@lindley.pe>  michael.quintanah@lindley.pe

# %%
DevOps.drop(columns =["Assigned to Email"], inplace = True)
DevOps.drop(columns =["Email2"], inplace = True)

# %%
DevOps.head()
# Out:
#      ID Work Item Type                                              Title  \
# 0  8153     User Story                  Pase a producción del job TMTO202
# 1  8155     User Story  Modificación y eliminación de CyB en pipelines...
# 2  8157     User Story  Validación de Imperdonables con Agrupación Est...
# 3  8159     User Story         Retirar precio lista de notebook Customers
# 4  8162     User Story   migración de MX a PE - ajuste proceso diario PS
#
#     State Tags                 Iteration Path        Closed Date  \
# 0  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 09:04:10
# 1  Closed  NaN  MXAdvancedAnalytics\Sprint 81  2/9/2022 18:21:42
# 2  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 13:08:56
# 3  Closed  NaN  PEAdvancedAnalytics\Sprint 43  1/9/2022 16:57:07
# 4  Closed  NaN  PEAdvancedAnalytics\Sprint 43  9/9/2022 10:13:40
#
#       Activated Date       Created Date  \
# 0  1/9/2022 09:03:57  1/9/2022 09:03:27
# 1  1/9/2022 09:07:27  1/9/2022 09:07:04
# 2  1/9/2022 12:54:49  1/9/2022 12:30:55
# 3  1/9/2022 16:15:39  1/9/2022 16:15:35
# 4  9/9/2022 10:05:17  1/9/2022 18:17:30
#
#                                          Description Assigned to Name  \
# 0  <div>Enviar a producción (correo a Mireles) de...   Carlos Prieto
# 1  <div>Modificar pipeline de PS para eliminar lo...   Carlos Prieto
# 2  <div>Validar cambios en imperdonables con arch...   Carlos Prieto
# 3  <div>Se debe eliminar la fuente de Precio list...   Carlos Aquino
# 4  <div>migración del ajuste diario en PS - adapt...      DS Michael
#
#                           Email
# 0  carlos.prieto@arcacontal.com
# 1  carlos.prieto@arcacontal.com
# 2  carlos.prieto@arcacontal.com
# 3     carlos.aquinop@lindley.pe
# 4  michael.quintanah@lindley.pe

# %%
DevOps["Email"].value_counts()
# Out:
# edmundo.reyes@ext.arcacontal.com     28
# juan.loerat@arcacontal.com           26
# diego.mavila@lindley.pe              16
# donaldo.salazar@arcacontal.com       15
# diego.garcias@arcacontal.com         14
# lizzie.canamar@arcacontal.com        14
# veronica.castillom@arcacontal.com    13
# carlos.prieto@arcacontal.com         11
# arnold.condor@lindley.pe             10
# carlos.aquinop@lindley.pe             9
# brissa.romero@ext.arcacontal.com      8
# cesar.rochah@arcacontal.com           8
# jesus.hinojosa@arcacontal.com         6
# isidro.reyes@arcacontal.com           5
# michael.quintanah@lindley.pe          5
# viviana.vazquez@arcacontal.com        3
# felipe.chairez@arcacontal.com         3
# raul.martinezt@arcacontal.com         3
# Name: Email, dtype: int64

# %%
conditions = [
    (DevOps["Email"] == "veronica.castillom@arcacontal.com") | 
    (DevOps["Email"] == "edmundo.reyes@ext.arcacontal.com") |
    (DevOps["Email"] == "juan.loerat@arcacontal.com") |
    (DevOps["Email"] == "diego.mavila@lindley.pe") |
    (DevOps["Email"] == "isidro.reyes@arcacontal.com")
    ,
    (DevOps["Email"] == "lizzie.canamar@arcacontal.com") |
    (DevOps["Email"] == "diego.garcias@arcacontal.com") |
    (DevOps["Email"] == "donaldo.salazar@arcacontal.com") |
    (DevOps["Email"] == "carlos.prieto@arcacontal.com") |
    (DevOps["Email"] == "viviana.vazquez@arcacontal.com") |
    (DevOps["Email"] == "carlos.aquinop@lindley.pe") |
    (DevOps["Email"] == "luis.cepeda@arcacontal.com") |
    (DevOps["Email"] == "ivan.ramirezm@arcacontal.com")
    ,
    (DevOps["Email"] == "arnold.condor@lindley.pe") |
    (DevOps["Email"] == "jesus.hinojosa@arcacontal.com") |
    (DevOps["Email"] == "michael.quintanah@lindley.pe") |
    (DevOps["Email"] == "alejandro.balderas@ext.arcacontal.com") |
    (DevOps["Email"] == "cesar.rochah@arcacontal.com") |
    (DevOps["Email"] == "brissa.romero@ext.arcacontal.com") |
    (DevOps["Email"] == "felipe.chairez@arcacontal.com") |
    (DevOps["Email"] == "raul.martinezt@arcacontal.com") |
    (DevOps["Email"] == "jose.moralesv@arcacontal.com")
    ]

# %%
values = ["Data Translators", "Data Engineer", "Data Scientist"]

# %%
DevOps["Area"] = np.select(conditions, values)

# %%
DevOps.head()
# Out:
#      ID Work Item Type                                              Title  \
# 0  8153     User Story                  Pase a producción del job TMTO202
# 1  8155     User Story  Modificación y eliminación de CyB en pipelines...
# 2  8157     User Story  Validación de Imperdonables con Agrupación Est...
# 3  8159     User Story         Retirar precio lista de notebook Customers
# 4  8162     User Story   migración de MX a PE - ajuste proceso diario PS
#
#     State Tags                 Iteration Path        Closed Date  \
# 0  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 09:04:10
# 1  Closed  NaN  MXAdvancedAnalytics\Sprint 81  2/9/2022 18:21:42
# 2  Closed  NaN  MXAdvancedAnalytics\Sprint 81  1/9/2022 13:08:56
# 3  Closed  NaN  PEAdvancedAnalytics\Sprint 43  1/9/2022 16:57:07
# 4  Closed  NaN  PEAdvancedAnalytics\Sprint 43  9/9/2022 10:13:40
#
#       Activated Date       Created Date  \
# 0  1/9/2022 09:03:57  1/9/2022 09:03:27
# 1  1/9/2022 09:07:27  1/9/2022 09:07:04
# 2  1/9/2022 12:54:49  1/9/2022 12:30:55
# 3  1/9/2022 16:15:39  1/9/2022 16:15:35
# 4  9/9/2022 10:05:17  1/9/2022 18:17:30
#
#                                          Description Assigned to Name  \
# 0  <div>Enviar a producción (correo a Mireles) de...   Carlos Prieto
# 1  <div>Modificar pipeline de PS para eliminar lo...   Carlos Prieto
# 2  <div>Validar cambios en imperdonables con arch...   Carlos Prieto
# 3  <div>Se debe eliminar la fuente de Precio list...   Carlos Aquino
# 4  <div>migración del ajuste diario en PS - adapt...      DS Michael
#
#                           Email            Area
# 0  carlos.prieto@arcacontal.com   Data Engineer
# 1  carlos.prieto@arcacontal.com   Data Engineer
# 2  carlos.prieto@arcacontal.com   Data Engineer
# 3     carlos.aquinop@lindley.pe   Data Engineer
# 4  michael.quintanah@lindley.pe  Data Scientist

# %%
DevOps["Iteration Path"].value_counts()
# Out:
# MXAdvancedAnalytics\Sprint 83     43
# MXAdvancedAnalytics\Sprint 82     28
# PEAdvancedAnalytics\Sprint 45     27
# ECAdvancedAnalytics\Sprint 25     27
# ECAdvancedAnalytics\Sprint 26     27
# ARGAdvancedAnalytics\Sprint 12    17
# PEAdvancedAnalytics\Sprint 44     14
# MXAdvancedAnalytics               12
# MXAdvancedAnalytics\Sprint 81      7
# PEAdvancedAnalytics\Sprint 43      6
# ECAdvancedAnalytics                4
# PEAdvancedAnalytics                4
# ARGAdvancedAnalytics               2
# ECAdvancedAnalytics\Sprint 24      1
# Name: Iteration Path, dtype: int64

# %%
LastSprint = ["MXAdvancedAnalytics\Sprint 82", "ECAdvancedAnalytics\Sprint 25", "PEAdvancedAnalytics\Sprint 44"]
DFSprint = pd.DataFrame(DevOps[DevOps["Iteration Path"].isin(LastSprint)])

# %%
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#            Closed Date      Activated Date        Created Date  \
# 5   23/9/2022 18:02:40   1/9/2022 20:01:13   1/9/2022 19:47:08
# 6   23/9/2022 18:02:40   1/9/2022 20:04:43   1/9/2022 19:48:17
# 12  28/9/2022 09:16:04   8/9/2022 09:17:26   8/9/2022 09:15:33
# 16  28/9/2022 16:31:00  12/9/2022 09:14:43  12/9/2022 08:22:44
# 17  26/9/2022 08:40:21  13/9/2022 09:18:08  13/9/2022 09:13:45
#
#                                           Description Assigned to Name  \
# 5   <div>Se integrará la fuente de ordenes del día...     César Rocha
# 6   <div>Para el release de Plataforma PS, el equi...     César Rocha
# 12  <div>&nbsp;Validar impacto de cambio en prodke...   Brissa Romero
# 16  <div>Crear una fuente utilizando los datos de ...   Carlos Prieto
# 17  <div>Se analizará el origen de la incidencia d...   arnold.condor
#
#                                Email            Area
# 5        cesar.rochah@arcacontal.com  Data Scientist
# 6        cesar.rochah@arcacontal.com  Data Scientist
# 12  brissa.romero@ext.arcacontal.com  Data Scientist
# 16      carlos.prieto@arcacontal.com   Data Engineer
# 17          arnold.condor@lindley.pe  Data Scientist

# %%
conditions2 =  [
    (DFSprint["Iteration Path"] == "MXAdvancedAnalytics\Sprint 82") ,
    (DFSprint["Iteration Path"] == "ECAdvancedAnalytics\Sprint 25") ,
    (DFSprint["Iteration Path"] == "PEAdvancedAnalytics\Sprint 44")
    ]
values2 = ["MX", "EC", "PE"]

# %%
DFSprint["BU"] = np.select(conditions2, values2)
DFSprint
# Out:
#        ID Work Item Type                                              Title  \
# 5    8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6    8168     User Story  Plataforma PS: Formato de entregas para client...
# 12   8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16   8240     User Story                    Crear fuente con datos de CENSO
# 17   8248     User Story  Diagnostico de Clientes con MKT size potencial...
# ..    ...            ...                                                ...
# 120  8619     User Story            Excluir clientes con PXC de reporte MPR
# 121  8625     User Story                       apoyo a DTs en visita de PXC
# 125  8631     User Story                                  Evaluación de H2O
# 129  8645     User Story                               PxC Visita Chihuahua
# 130  8647     User Story                           correo diario PS MX Trad
#
#       State              Tags                 Iteration Path  \
# 5    Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6    Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16   Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17   Closed               NaN  PEAdvancedAnalytics\Sprint 44
# ..      ...               ...                            ...
# 120  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 121  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 125  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 129  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 130  Closed               NaN  MXAdvancedAnalytics\Sprint 82
#
#             Closed Date      Activated Date        Created Date  \
# 5    23/9/2022 18:02:40   1/9/2022 20:01:13   1/9/2022 19:47:08
# 6    23/9/2022 18:02:40   1/9/2022 20:04:43   1/9/2022 19:48:17
# 12   28/9/2022 09:16:04   8/9/2022 09:17:26   8/9/2022 09:15:33
# 16   28/9/2022 16:31:00  12/9/2022 09:14:43  12/9/2022 08:22:44
# 17   26/9/2022 08:40:21  13/9/2022 09:18:08  13/9/2022 09:13:45
# ..                  ...                 ...                 ...
# 120  6/10/2022 08:38:13  6/10/2022 07:42:27  6/10/2022 07:41:53
# 121  6/10/2022 09:10:00  6/10/2022 09:10:00  6/10/2022 09:09:54
# 125  7/10/2022 11:31:45  6/10/2022 11:03:31  6/10/2022 10:59:48
# 129  7/10/2022 15:08:05  7/10/2022 15:08:05  7/10/2022 15:06:44
# 130  7/10/2022 15:26:14  7/10/2022 15:26:14  7/10/2022 15:25:10
#
#                                            Description  \
# 5    <div>Se integrará la fuente de ordenes del día...
# 6    <div>Para el release de Plataforma PS, el equi...
# 12   <div>&nbsp;Validar impacto de cambio en prodke...
# 16   <div>Crear una fuente utilizando los datos de ...
# 17   <div>Se analizará el origen de la incidencia d...
# ..                                                 ...
# 120                                                NaN
# 121  <div>se solicitó el apoyo a los DTs en las vis...
# 125  <div>Evaluación de los resultados del modelo d...
# 129  <div>Se realizará la visita a Chiuahua para el...
# 130  <div>correo diario de seguimiento al cumplimie...
#
#                         Assigned to Name                             Email  \
# 5                           César Rocha        cesar.rochah@arcacontal.com
# 6                           César Rocha        cesar.rochah@arcacontal.com
# 12                        Brissa Romero   brissa.romero@ext.arcacontal.com
# 16                        Carlos Prieto       carlos.prieto@arcacontal.com
# 17                        arnold.condor           arnold.condor@lindley.pe
# ..                                   ...                               ...
# 120  Lizzie Montserrat Canamar Carrillo      lizzie.canamar@arcacontal.com
# 121                 EDMUNDO REYES JAIME   edmundo.reyes@ext.arcacontal.com
# 125                         César Rocha        cesar.rochah@arcacontal.com
# 129             Juan Carlos Loera Tovar         juan.loerat@arcacontal.com
# 130                 EDMUNDO REYES JAIME   edmundo.reyes@ext.arcacontal.com
#
#                  Area  BU
# 5      Data Scientist  MX
# 6      Data Scientist  MX
# 12     Data Scientist  MX
# 16      Data Engineer  MX
# 17     Data Scientist  PE
# ..                ...  ..
# 120     Data Engineer  MX
# 121  Data Translators  MX
# 125    Data Scientist  MX
# 129  Data Translators  MX
# 130  Data Translators  MX
#
# [69 rows x 14 columns]

# %%
DFSprint["State"].value_counts()
# Out:
# Closed    68
# Active     1
# Name: State, dtype: int64

# %%
result = DFSprint.dtypes
result
# Out:
# ID                   int64
# Work Item Type      object
# Title               object
# State               object
# Tags                object
# Iteration Path      object
# Closed Date         object
# Activated Date      object
# Created Date        object
# Description         object
# Assigned to Name    object
# Email               object
# Area                object
# BU                  object
# dtype: object

# %%
DO3 = DFSprint["Closed Date"].str.split(" ", n = 1, expand = True)
DFSprint["Closed_Date"]= DO3[0]
DFSprint["Hours"]= DO3[1]
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#            Closed Date      Activated Date        Created Date  \
# 5   23/9/2022 18:02:40   1/9/2022 20:01:13   1/9/2022 19:47:08
# 6   23/9/2022 18:02:40   1/9/2022 20:04:43   1/9/2022 19:48:17
# 12  28/9/2022 09:16:04   8/9/2022 09:17:26   8/9/2022 09:15:33
# 16  28/9/2022 16:31:00  12/9/2022 09:14:43  12/9/2022 08:22:44
# 17  26/9/2022 08:40:21  13/9/2022 09:18:08  13/9/2022 09:13:45
#
#                                           Description Assigned to Name  \
# 5   <div>Se integrará la fuente de ordenes del día...     César Rocha
# 6   <div>Para el release de Plataforma PS, el equi...     César Rocha
# 12  <div>&nbsp;Validar impacto de cambio en prodke...   Brissa Romero
# 16  <div>Crear una fuente utilizando los datos de ...   Carlos Prieto
# 17  <div>Se analizará el origen de la incidencia d...   arnold.condor
#
#                                Email            Area  BU Closed_Date     Hours
# 5        cesar.rochah@arcacontal.com  Data Scientist  MX   23/9/2022  18:02:40
# 6        cesar.rochah@arcacontal.com  Data Scientist  MX   23/9/2022  18:02:40
# 12  brissa.romero@ext.arcacontal.com  Data Scientist  MX   28/9/2022  09:16:04
# 16      carlos.prieto@arcacontal.com   Data Engineer  MX   28/9/2022  16:31:00
# 17          arnold.condor@lindley.pe  Data Scientist  PE   26/9/2022  08:40:21

# %%
DO4 = DFSprint["Activated Date"].str.split(" ", n = 1, expand = True)
DFSprint["Activated_Date"]= DO4[0]
DFSprint["Hours2"]= DO4[1]
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#            Closed Date      Activated Date        Created Date  \
# 5   23/9/2022 18:02:40   1/9/2022 20:01:13   1/9/2022 19:47:08
# 6   23/9/2022 18:02:40   1/9/2022 20:04:43   1/9/2022 19:48:17
# 12  28/9/2022 09:16:04   8/9/2022 09:17:26   8/9/2022 09:15:33
# 16  28/9/2022 16:31:00  12/9/2022 09:14:43  12/9/2022 08:22:44
# 17  26/9/2022 08:40:21  13/9/2022 09:18:08  13/9/2022 09:13:45
#
#                                           Description Assigned to Name  \
# 5   <div>Se integrará la fuente de ordenes del día...     César Rocha
# 6   <div>Para el release de Plataforma PS, el equi...     César Rocha
# 12  <div>&nbsp;Validar impacto de cambio en prodke...   Brissa Romero
# 16  <div>Crear una fuente utilizando los datos de ...   Carlos Prieto
# 17  <div>Se analizará el origen de la incidencia d...   arnold.condor
#
#                                Email            Area  BU Closed_Date  \
# 5        cesar.rochah@arcacontal.com  Data Scientist  MX   23/9/2022
# 6        cesar.rochah@arcacontal.com  Data Scientist  MX   23/9/2022
# 12  brissa.romero@ext.arcacontal.com  Data Scientist  MX   28/9/2022
# 16      carlos.prieto@arcacontal.com   Data Engineer  MX   28/9/2022
# 17          arnold.condor@lindley.pe  Data Scientist  PE   26/9/2022
#
#        Hours Activated_Date    Hours2
# 5   18:02:40       1/9/2022  20:01:13
# 6   18:02:40       1/9/2022  20:04:43
# 12  09:16:04       8/9/2022  09:17:26
# 16  16:31:00      12/9/2022  09:14:43
# 17  08:40:21      13/9/2022  09:18:08

# %%
DFSprint.drop(columns =["Closed Date"], inplace = True)
DFSprint.drop(columns =["Activated Date"], inplace = True)
DFSprint.drop(columns =["Hours"], inplace = True)
DFSprint.drop(columns =["Hours2"], inplace = True)

# %%
DFSprint["Closed_Date"] = pd.to_datetime(DFSprint["Closed_Date"], dayfirst=True)
DFSprint["Activated_Date"] = pd.to_datetime(DFSprint["Activated_Date"], dayfirst=True)

# %%
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#           Created Date                                        Description  \
# 5    1/9/2022 19:47:08  <div>Se integrará la fuente de ordenes del día...
# 6    1/9/2022 19:48:17  <div>Para el release de Plataforma PS, el equi...
# 12   8/9/2022 09:15:33  <div>&nbsp;Validar impacto de cambio en prodke...
# 16  12/9/2022 08:22:44  <div>Crear una fuente utilizando los datos de ...
# 17  13/9/2022 09:13:45  <div>Se analizará el origen de la incidencia d...
#
#    Assigned to Name                             Email            Area  BU  \
# 5      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 6      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 12   Brissa Romero   brissa.romero@ext.arcacontal.com  Data Scientist  MX
# 16   Carlos Prieto       carlos.prieto@arcacontal.com   Data Engineer  MX
# 17   arnold.condor           arnold.condor@lindley.pe  Data Scientist  PE
#
#    Closed_Date Activated_Date
# 5   2022-09-23     2022-09-01
# 6   2022-09-23     2022-09-01
# 12  2022-09-28     2022-09-08
# 16  2022-09-28     2022-09-12
# 17  2022-09-26     2022-09-13

# %%
result = DFSprint.dtypes
result
# Out:
# ID                           int64
# Work Item Type              object
# Title                       object
# State                       object
# Tags                        object
# Iteration Path              object
# Created Date                object
# Description                 object
# Assigned to Name            object
# Email                       object
# Area                        object
# BU                          object
# Closed_Date         datetime64[ns]
# Activated_Date      datetime64[ns]
# dtype: object

# %%
DFSprint["TimeToComplete"] = DFSprint["Closed_Date"] - DFSprint["Activated_Date"]

# %%
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#           Created Date                                        Description  \
# 5    1/9/2022 19:47:08  <div>Se integrará la fuente de ordenes del día...
# 6    1/9/2022 19:48:17  <div>Para el release de Plataforma PS, el equi...
# 12   8/9/2022 09:15:33  <div>&nbsp;Validar impacto de cambio en prodke...
# 16  12/9/2022 08:22:44  <div>Crear una fuente utilizando los datos de ...
# 17  13/9/2022 09:13:45  <div>Se analizará el origen de la incidencia d...
#
#    Assigned to Name                             Email            Area  BU  \
# 5      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 6      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 12   Brissa Romero   brissa.romero@ext.arcacontal.com  Data Scientist  MX
# 16   Carlos Prieto       carlos.prieto@arcacontal.com   Data Engineer  MX
# 17   arnold.condor           arnold.condor@lindley.pe  Data Scientist  PE
#
#    Closed_Date Activated_Date TimeToComplete
# 5   2022-09-23     2022-09-01        22 days
# 6   2022-09-23     2022-09-01        22 days
# 12  2022-09-28     2022-09-08        20 days
# 16  2022-09-28     2022-09-12        16 days
# 17  2022-09-26     2022-09-13        13 days

# %%
result2 = DFSprint.dtypes
result2
# Out:
# ID                            int64
# Work Item Type               object
# Title                        object
# State                        object
# Tags                         object
# Iteration Path               object
# Created Date                 object
# Description                  object
# Assigned to Name             object
# Email                        object
# Area                         object
# BU                           object
# Closed_Date          datetime64[ns]
# Activated_Date       datetime64[ns]
# TimeToComplete      timedelta64[ns]
# dtype: object

# %%
DFSprint['Days to Complete'] = DFSprint['TimeToComplete'].dt.days
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#           Created Date                                        Description  \
# 5    1/9/2022 19:47:08  <div>Se integrará la fuente de ordenes del día...
# 6    1/9/2022 19:48:17  <div>Para el release de Plataforma PS, el equi...
# 12   8/9/2022 09:15:33  <div>&nbsp;Validar impacto de cambio en prodke...
# 16  12/9/2022 08:22:44  <div>Crear una fuente utilizando los datos de ...
# 17  13/9/2022 09:13:45  <div>Se analizará el origen de la incidencia d...
#
#    Assigned to Name                             Email            Area  BU  \
# 5      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 6      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 12   Brissa Romero   brissa.romero@ext.arcacontal.com  Data Scientist  MX
# 16   Carlos Prieto       carlos.prieto@arcacontal.com   Data Engineer  MX
# 17   arnold.condor           arnold.condor@lindley.pe  Data Scientist  PE
#
#    Closed_Date Activated_Date TimeToComplete  Days to Complete
# 5   2022-09-23     2022-09-01        22 days              22.0
# 6   2022-09-23     2022-09-01        22 days              22.0
# 12  2022-09-28     2022-09-08        20 days              20.0
# 16  2022-09-28     2022-09-12        16 days              16.0
# 17  2022-09-26     2022-09-13        13 days              13.0

# %%
DFSprint["Time Active"] = np.where(DFSprint["Days to Complete"]> 5, "Warning", "On Time")

# %%
DFSprint.drop(columns =["TimeToComplete"], inplace = True)
DFSprint.head()
# Out:
#       ID Work Item Type                                              Title  \
# 5   8167     User Story        Plataforma PS: Compensa con ordenes del día
# 6   8168     User Story  Plataforma PS: Formato de entregas para client...
# 12  8218     User Story        PDV - Validar impacto de cambio en prodkeys
# 16  8240     User Story                    Crear fuente con datos de CENSO
# 17  8248     User Story  Diagnostico de Clientes con MKT size potencial...
#
#      State              Tags                 Iteration Path  \
# 5   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 6   Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 12  Closed               NaN  MXAdvancedAnalytics\Sprint 82
# 16  Closed  Data Engineering  MXAdvancedAnalytics\Sprint 82
# 17  Closed               NaN  PEAdvancedAnalytics\Sprint 44
#
#           Created Date                                        Description  \
# 5    1/9/2022 19:47:08  <div>Se integrará la fuente de ordenes del día...
# 6    1/9/2022 19:48:17  <div>Para el release de Plataforma PS, el equi...
# 12   8/9/2022 09:15:33  <div>&nbsp;Validar impacto de cambio en prodke...
# 16  12/9/2022 08:22:44  <div>Crear una fuente utilizando los datos de ...
# 17  13/9/2022 09:13:45  <div>Se analizará el origen de la incidencia d...
#
#    Assigned to Name                             Email            Area  BU  \
# 5      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 6      César Rocha        cesar.rochah@arcacontal.com  Data Scientist  MX
# 12   Brissa Romero   brissa.romero@ext.arcacontal.com  Data Scientist  MX
# 16   Carlos Prieto       carlos.prieto@arcacontal.com   Data Engineer  MX
# 17   arnold.condor           arnold.condor@lindley.pe  Data Scientist  PE
#
#    Closed_Date Activated_Date  Days to Complete Time Active
# 5   2022-09-23     2022-09-01              22.0     Warning
# 6   2022-09-23     2022-09-01              22.0     Warning
# 12  2022-09-28     2022-09-08              20.0     Warning
# 16  2022-09-28     2022-09-12              16.0     Warning
# 17  2022-09-26     2022-09-13              13.0     Warning

# %%
DFSprint["Days to Complete"].max()
# Out:
# 22.0

# %%
Grafica1 = DFSprint[["Days to Complete", "Area", "BU"]]
Grafica2 = Grafica1.groupby(["Area", "BU"]).mean()
GR = Grafica2.sort_values(by="Days to Complete", ascending=True)

GR.plot(kind = "barh")
plt.savefig("AreaBUGraph.jpg")

# %%
GR.max()
# Out:
# Days to Complete    10.625
# dtype: float64

# %%
Actividades = DFSprint[["Days to Complete", "Assigned to Name"]]
Actividades1 = Actividades.groupby(["Assigned to Name"]).mean()
Actividades2 = Actividades1.sort_values(by="Days to Complete", ascending=True)

Actividades2.plot(kind="barh", figsize=(20,20))
plt.savefig("TeamMember.jpg")

# %%
DFWarning = DFSprint[DFSprint["Time Active"] == "Warning"][["Assigned to Name","Title","Description","Area","BU"]]

# %%
DFWarning.to_excel("RevisarActividades.xlsx")
print("DataFrame is written to Excel File successfully.")
# Out:
# DataFrame is written to Excel File successfully.
